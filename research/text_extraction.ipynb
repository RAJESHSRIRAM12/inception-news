# %%
#### Testing with trafilatura libraries

# %%
# !pip install trafilatura
# Out:
# ...
#   Using cached lxml-6.0.2-cp313-cp313-win_amd64.whl.metadata (3.7 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached regex-2026.1.15-cp313-cp313-win_amd64.whl.metadata (41 kB)
# ...
#   Using cached lxml_html_clean-0.4.3-py3-none-any.whl.metadata (2.3 kB)
# ...
#    ---------------------------------------- 0.0/837.9 kB ? eta -:--:--
#    --------------------------------------- 837.9/837.9 kB 12.4 MB/s eta 0:00:00
# Using cached lxml-6.0.2-cp313-cp313-win_amd64.whl (4.0 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached regex-2026.1.15-cp313-cp313-win_amd64.whl (277 kB)
# ...
# Using cached lxml_html_clean-0.4.3-py3-none-any.whl (14 kB)
# ...
#
#    ----------------------------------------  0/11 [pytz]
#    --- ------------------------------------  1/11 [tzlocal]
#    -------------- -------------------------  4/11 [lxml]
#    -------------- -------------------------  4/11 [lxml]
#    --------------------- ------------------  6/11 [dateparser]
# ...

# %%
# !pip install feedfinder2
# Out:
# ...
#   Using cached feedfinder2-0.0.4-py3-none-any.whl
# ...
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from feedfinder2 import find_feeds


feeds = find_feeds("https://www.dw.com")
number_of_feeds = len(feeds)
print(number_of_feeds)
for i in feeds:
    print(i)
# Out:
# 0

# %%
#### feedpaser -- standard library for RSS/Atomparsing


# !pip install feedparser
# Out:
# ...
#   Using cached feedparser-6.0.12-py3-none-any.whl.metadata (2.7 kB)
# ...
#   Using cached sgmllib3k-1.0.0-py3-none-any.whl
# Using cached feedparser-6.0.12-py3-none-any.whl (81 kB)
# ...
#
#    ---------------------------------------- 2/2 [feedparser]
#
# ...
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#### For DW rss are not made in opensite
#### But stored as RSS Feed ####

rss_dw = "https://rss.dw.com/rdf/rss-en-all"
rss_dw_atom = "https://rss.dw.com/atom/rss-en-all"

# %%
import feedparser

feed = feedparser.parse("https://rss.dw.com/atom/rss-en-all")
print(feed)
# Out:
# {'bozo': False, 'entries': [{'id': 'tag:dw.com,2026:76011964', 'guidislink': True, 'link': 'https://www.dw.com/en/shein-faces-eu-investigation-over-products-design-features/a-76011964?maca=en-rss-en-all-1573-xml-atom', 'title': 'Shein faces EU investigation over products, design features', 'title_detail': {'type': 'text/plain', 'language': 'en', 'base': 'https://rss.dw.com/atom/rss-en-all', 'value': 'Shein faces EU investigation over products, design features'}, 'updated': '2026-02-17T19:48:00Z', 'updated_parsed': time.struct_time(tm_year=2026, tm_mon=2, tm_mday=17, tm_hour=19, tm_min=48, tm_sec=0, tm_wday=1, tm_yday=48, tm_isdst=0), 'published': '2026-02-17T19:48:00Z', 'published_parsed': time.struct_time(tm_year=2026, tm_mon=2, tm_mday=17, tm_hour=19, tm_min=48, tm_sec=0, tm_wday=1, tm_yday=48, tm_isdst=0), 'rights': '2026 DW', 'rights_detail': {'type': 'text/plain', 'language': 'en', 'base': 'https://rss.dw.com/atom/rss-en-all', 'value': '2026 DW'}, 'links': [{'rel': 'alternate', 
# ...

# %%
import trafilatura as tr
#### Entries is where everything is stored ######
number_of_entries = len(feed.entries)
print(number_of_entries)

for entries in feed.entries:
    link = entries.link
    downloaded = tr.fetch_url(link)
    result = tr.extract(downloaded)
    print(result)
# Out:
# 142
# Shein faces EU investigation over products, design features
# February 17, 2026The European Commission said on Tuesday that it had opened formal proceedings against Shein under its Digital Services Act (DSA).
# It said that regulators would investigate the Chinese-founded discount fashion retailer that does most of its business online for "its addictive design, the lack of transparency of recommender systems, as well as the sale of illegal products, including child sexual abuse material."
# Shein may be required to either alter its actions, or face potentially hefty fines if a so-called non-compliance decision is reached following the investigation.
# The 27-member EU's executive branch said it was not yet possible to say how long the investigations would take and stressed it was only announcing an in-depth investigation, not findings of wrongdoing.
# What will the investigation focus on?
# The Commission said that the investigation would focus on several areas, most notably:
# ...

# %%
import trafilatura as tr

url = "https://www.dw.com/de/themen/s-9077"
downloaded = tr.fetch_url(url)
result = tr.extract(downloaded)
